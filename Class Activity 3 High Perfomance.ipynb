# %% [markdown]
# Class Activity 3 High Perfomance Computing

# %% [markdown]
# ***Part 1 Benchmarking and Profiling***

# %% [markdown]
# 1 Read the sections“Introducing the Julia Set”and “Calculating the Full Julia Set”on Chapter  2.  Profiling  to  Find  Bottlenecksfrom  the book: M.  Gorelick  &  I.  Ozsvald (2020). High Performance Python. Practical Performant Programming for Humans.Second  Edition.  United  States  of  America:  O’Reilly  Media,  Inc.Implement  the chapter functions(Example2-1, 2-2, 2-3 and 2-4)on Python in order to calculate the Julia Set. Make the representation for the false gray and pure gray scale.

# %% [markdown]
# ![alt text](Juliasetplot.jpeg)

# %% [markdown]
# ![alt text](EvolutionJuliaset.jpeg)

# %% [markdown]
# 2 Define a new function, timefn, which takes a function as an argument: the inner
# function, measure_time, takes *args (a variable number of positional arguments)
# and **kwargs (a variable number of key/value arguments) and passes them through
# to fn for execution. Decorate calculate_z_serial_purepython with @timefn to profile
# it. Implement Example 2-5 and adapt your current source code

# %% [markdown]
# ![alt text](TimeitJulia].jpeg)

# %% [markdown]
# Length of x: 1000: This indicates that 1000 points have been generated along the x-axis in the complex plane. These points are used as the real part of the complex numbers for which the Julia set is calculated.
#
# Total elements: 1000000: This suggests that the script has created a grid with 1,000,000 points in total (1000 x-axis points times 1000 y-axis points) in the complex plane.
#
# Timing Output:
# The @timefn: calculate_z_serial_purepython took 5.927441358566284 seconds: This line shows the time taken by the calculate_z_serial_purepython function to perform the Julia set calculation. The @timefn decorator has printed this output, which includes the name of the function and the time taken to execute it. The execution time is approximately 5.93 seconds.

# %% [markdown]
# 3 Use the timeit modeule to get a coarse measurement of the execution speed of the
# CPU-bound function. Runs 10 loops with 5 repetitions. Show how to do the
# measurement on the command line and on a Jupyter Notebook.

# %% [markdown]
# ![alt text](Part1.3.jpeg)

# %% [markdown]
# -The average execution time per loop (execution of the function) is approximately 6.04 seconds.
#
# -The standard deviation is about 464 milliseconds, which gives a sense of the variability in the execution time across different runs.
#
# -These measurements are based on 7 runs, with each run executing the function once (1 loop each).

# %% [markdown]
# Use the cProfile module to profile the source code (.py). Sort the results by the time
# spent inside each function. This will give a view into the slowest parts. Analyze the
# output and make a syntesis of the findings. Show how to use the cProfile module on
# the command line and on a Jupyter Notebook.

# %% [markdown]
# ![alt text](Part1.4.jpeg)

# %% [markdown]
# 1. Total Function Calls: The profiler recorded 3,422,0170 function calls during the execution of your program.
#
# 2. Total Execution Time: The total execution time for the profiled code was 15.857 seconds.
#
# 3. Ordered by Cumulative Time: The list of function calls is sorted by "cumulative time," which is the total time spent in the function and all the functions it called.
#
# 4. Top Functions: The list has been reduced to show only the top 10 functions due to the restriction <10. This typically means that only functions that take at least 10% of the cumulative time are listed.
#
# 5. The specific functions listed include:
#
# {built-in method builtins.exec}: The execution of the code block provided to cProfile.
#
# <string>:1(<module>): This is likely the entry point of the profiling, invoking the calc_pure_python function.
#
# calc_pure_python: This function sets up the complex plane and calls calculate_z_serial_purepython to compute the Julia set.
#
# calculate_z_serial_purepython: The main function that calculates the Julia set.
#
# 6. Execution Time Details:
#
# The calculate_z_serial_purepython function has the highest total time (tottime) with 10.543 seconds, which indicates that it is the most computationally intensive part of the program.
# The listcomp entries correspond to list comprehensions in the calc_pure_python function, which are the next most time-consuming parts of the code.
#
# 7. Time per Call: The percall column next to tottime and cumtime is the average time per call, computed by dividing the total time by the number of calls (ncalls).

# %% [markdown]
# 5 Use snakeviz to get a high-level understanding of the cPrifile statistics file. Analyze
# the output and make a syntesis of the findings.

# %% [markdown]
# ![alt text](Part1.5.0.jpeg)

# %% [markdown]
# ![alt text](Part1.5.2.jpeg)

# %% [markdown]
# ![alt text](Part1.5.3.jpeg)

# %% [markdown]
# 6 Use the line_profiler and kernprof file to profile line-by-line the function
# calculate_z_serial_purepython. Analyze the output and make a syntesis of the
# findings.

# %% [markdown]
# ![alt text](Part1.6.jpeg)

# %% [markdown]
# The profiling data is indicating that the lines inside the while loop of the calculate_z_serial_purepython function are where the program spends most of its time, which is typical for this kind of fractal computation since it involves many iterations for each point in the complex plane to determine if it's part of the Julia set or not. These lines are the primary candidates for optimization if one were looking to improve the program's performance.

# %% [markdown]
# 7 Use the memory_profiler to diagnose memory usage. Analyze the output and make
# a syntesis of the findings

# %% [markdown]
# ![alt text](Part1.7.jpeg)

# %% [markdown]
# The profiler output suggests that the function's memory usage is mostly stable after the initial allocation for the output list. However, the long execution time indicates that the computational efficiency of the function could be improved. The negative increments in memory may require a closer look to understand the memory dynamics better, possibly by inspecting the behavior of the program with finer-grained sampling or in a different runtime context.

# %% [markdown]
# ***Part 2 List and Tuples***

# %% [markdown]
# 8. In some cases, it is necessary to efficiently perform insertion or removal of elements
# both at the beginning and at the end of the collection. Measure the time for the
# following operations with N = 10 000, 20 000 y 30 000 elements:
#
# a. Delete last element of a list via pop()
#
# b. Delete first element of a list via pop(0)
#
# c. Append 1 at the end of the list.
#
# d. Insert 1 at the beginning of the list insert(0, 1)
#
#
# Make a table with your results. It should looks like table on Chapter 2: Pure Python
# Optimization (pp. 38) from the book G. Lenaro (2017). Python high Performance.
# Second Edition. UK: Packt Publishing Ltd

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The trends shown in the table align with the expected complexities of these operations. It's worth noting that the times for list.pop() and list.append(1) seem counterintuitive in some cases (e.g., faster at N=30000 than at N=10000), which may be due to variations in the execution environment or the overhead of the timeit setup.

# %% [markdown]
# 9. Python provides a data structure with interesting properties in the collection.deque
# class. The word deque stands for double-ended queue because this data structure
# is designed to efficiently put and remove elements at the beginning and at the end
# of the collection. Evaluate the following methods with N = 10 000, 20 000 and 30
# 000 elements:
#
# a. deque.pop()
#
# b. deque.popleft()
#
# c. deque.append(1)
#
# d. deque.appendleft(1)
#
# Make a table with your results. It should looks like table on pp. 39 on the same book
# as previous task.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The results from running the deque operations benchmarking script show the average execution times in microseconds for each operation at different deque sizes (N=10000, N=20000, N=30000).
#
# The timing variations could be due to several factors, including the overhead of the timeit function, the state of the Python interpreter, or system-related fluctuations. However, all operations demonstrate the efficiency of deque for both append and pop operations at either end, with no significant time increase as the size of the deque grows, affirming that deque is indeed optimized for such operations.

# %% [markdown]
# 10. The efficiency gained by the appendleft and popleft comes at a cost: accesing an
# element in the middle of a deque is a O(N) operation. Evaluate the time for the next
# operations with with N = 10 000, 20 000 and 30 000 elements:
#
# a. deque[0]
#
# b. deque[N-1]
#
# c. deque[int(N/2)]
#
# Make a table with your results. It should looks like table on pp. 39 on the same book
# as previous task.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The results indicate the average time taken to access the first, last, and middle elements of a deque for sizes 10,000, 20,000, and 30,000. The times are given in microseconds (µs).
#
# These results demonstrate that accessing the first and last elements of a deque is very fast and does not significantly change as the size of the deque increases, which is consistent with the O(1) time complexity of these operations.
#
# The slight variability in the times, especially the non-monotonic results for accessing the first element, might be due to overhead in the testing setup or variations in system load during the tests, but overall the times remain low. It's important to note that while the deque structure is optimized for operations at the ends, it is not designed for fast random access in the middle of the sequence, which is reflected in these results.

# %% [markdown]
# ***Part 3: Dictionaries and Sets***

# %% [markdown]
# 13. Use the marco geoestadístico 2010
# (https://www.inegi.org.mx/app/biblioteca/ficha.html?upc=889463807469) and
# 2020 (https://www.inegi.org.mx/app/biblioteca/ficha.html?upc=702825292812) to
# obtain the “Áreas Geoestadísticas Básicas” (AGEBs) from Mérida, Yucatán. AGEBs
# evolve on time. Use sets to find:
#
# a. AGEBs which remains from 2010 on 2020.
#
# b. New AGEBs on 2020.
#
# c. AGEBs that disappear from 2010 to 2020.
#
# Make a map with the following visualization to observe all three cases

# %% [markdown]
# a. AGEBs which remains from 2010 on 2020.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# b. New AGEBs on 2020.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# c. AGEBs that disappear from 2010 to 2020.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ***Part 4: Matrix and Vector Computations***

# %% [markdown]
# 13. Read about Broadcasting with Arrays on the chapter Computation on Arrays:
# Broadcasting from Python Data Science Handbook (J. VandePlas, 2016):
# Link: https://jakevdp.github.io/PythonDataScienceHandbook/02.05-computation-
# on-arrays-broadcasting.html.

# %% [markdown]
# 14. Read Rewriting the particle simulator in Numpy on Chapter 2: Fast Array Operations
# with Numpy and Pandas (pp. 68) from the book G. Lenaro (2017). Python high
# Performance. Second Edition. UK: Packt Publishing Ltd. Implement the
# improvements on the particle simulator using NumPy. Show that both
# implementations scale linearly with particle size, but the runtime in the pure Python
# version grows much faster than the NumPy version

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# As we can see, both implementations scale linearly with the number of particles. However, the runtime for the pure Python version grows much faster than the NumPy version. The NumPy implementation takes advantage of vectorized operations over arrays, which significantly reduces the computation time compared to the pure Python approach that relies on iterating over lists of particle objects.

# %% [markdown]
# 15. Explain how to optain the optimal performance with numexpr. Read the section
# Reaching optimal performance with numexpr, pp. 72 from the previous reference.
# Implement it and measure the execution time

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# As observed, while the execution time for both implementations increases with the number of particles, the rate of increase is much steeper for the pure Python version compared to the NumPy version. This graph effectively showcases the superior performance of NumPy for handling numerical computations, especially as the scale of the problem (in this case, the number of particles) grows.

# %% [markdown]
# ***Part 5: Compiling to C***

# %% [markdown]
# 16. Read about the Conway’s Game of Life. Implement all solutions provided on the
# Cython Material (slides) to obtain the update of the lattice:
#
# a. Python
#
# b. Cython 1
#
# c. Cython 2
#
# d. Cython 3
#
# e. Cython 4
#
# Explain the improvement on each solution. Reproduce the chart on pp. 33 with the
# runtime for each solution

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The chart shows that the Python implementation and Cython1 have the longest execution times, while Cython4 has the shortest, indicating the most efficient performance among the tested functions. This suggests that the optimizations made in Cython4 have a significant impact on performance compared to the other versions.
#
# The reduction in time from Python to Cython1 is noticeable, but Cython2, Cython3, and Cython4 show a trend of incremental improvements, with each subsequent version outperforming the previous. This is consistent with what you would expect when optimizing code using Cython: proper type declarations, reducing Python interaction, and other optimizations can lead to substantial performance gains.
